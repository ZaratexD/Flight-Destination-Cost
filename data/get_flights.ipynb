# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.delta.com/flightstatus/schedule/SEA/FCO/2024-06-03'

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send a GET request to the URL
response = requests.get(url, headers=headers)

# %%
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    #flights = soup.find_all(div)
    
    print(soup.find_all())
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
#
# <html class="fresh-air hp-legacy" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Flight Status</title>
# <base href="/flightstatus/"/>
# <meta content="Find the flight status for a specific Delta Air Lines flight and receive real-time notifications via text or email." name="description"/>
# <meta content="Flight Status &amp; Notifications" name="keywords"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
# <link href="https://www.delta.com/flightstatus/search" rel="canonical"/>
# <link href="//fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800" rel="stylesheet" type="text/css"/>
# <link href="/content/dam/delta-applications/fresh-air-core/24.4.0/css/fresh-air.css" rel="stylesheet"/>
# <link href="/content/dam/delta-applications/fresh-air-core/24.4.0/fonts/fresh-air-fonts.css" rel="stylesheet"/>
# <link href="styles.css" rel="stylesheet"/>
# <link data-css-include="true" href="/content/dam/delta-applications/aura/assets/fonts/aura-fonts.css" rel="stylesheet">
# <link data-css-include="true" href="/content/dam/delta-applications/aura/1.7.1/variables/aura-delta.variables.css" rel="stylesheet">
# <style>
#         .loader {
#             background: #FFF;
#             position: absolute;
#             width: 100%;
#             height: 100%;
#             z-index: 9;
#         }
#
#         .loader img {
#             position: absolute;
#             left: 50%;
#             top: 50%;
#             margin-left: -9px;
#             margin-top: -9px;
#         }
#     </style>
# <script async="" src="https://www.delta.com/resources/ced240f65c63120c0d0265eb98f27f913a30d77a1d98e" type="text/javascript"></script><script>
#     try {
#         var rhpr = false;
# 		window.rhpr = false;
# 		var isHomePage = false;
# 		window.isHomePage = false;
# 		window.isAuthor = false;
# 		window.departureCityWidget = false;
# 		window.cookiePolicyJSONObject = false;
# 		window.tmpLoginData = false;
# 		window.imgPath = false;
# 		window.delta = {
# 			utils : {
# 				celebrus: {
# 					useConfig: false
# 				},
# 				logger: {
# 					logMessage: console.log
# 				}
# 			}
# 		};
# 		window.trackJs = {
#           track: (error) => {
#             console.log(error);
#           }
#         };
#     } catch (e) {};
# </script>
# <script src="/content/dam/delta-applications/aura/1.7.1/aura-with-zone.js" type="text/javascript"></script>
# <script src="https://maps.googleapis.com/maps/api/js?client=gme-deltaairlinesinc&amp;v=3.46" type="text/javascript"></script>
# <!-- script for aws monitoring -->
# <script>(function(n,i,v,r,s,c,x,z){x=window.AwsRumClient={q:[],n:n,i:i,v:v,r:r,c:c};window[n]=function(c,p){x.q.push({c:c,p:p});};z=document.createElement('script');z.async=true;z.src=s;document.head.insertBefore(z,document.head.getElementsByTagName('script')[0]);})('cwr','c03f78a5-8c95-4273-9d51-a302173ab182','1.0.0','us-east-1','https://client.rum.us-east-1.amazonaws.com/1.2.1/cwr.js',{sessionSampleRate:1,guestRoleArn:"arn:aws:iam::054027319831:role/delegate-admin-brandcontent-cognito-identity",identityPoolId:"us-east-1:9524397e-e431-4715-a615-59a33ce4bd82",endpoint:"https://dataplane.rum.us-east-1.amazonaws.com",telemetries:["performance","errors","http"],allowCookies:true,enableXRay:true});</script>
# <script src="/content/dam/tealeaf/delta6_2TealeafUIC.js" type="text/javascript"></script>
# </link></link></head>
# <body class="delta flight-status">
# <idp-login-modal-profile-selector></idp-login-modal-profile-selector>
# <input class="aemrefreshurl" id="aemrefreshurl" type="hidden" value="/flightstatus/search"/>
# <dl-root>
# <em class="loader">
# <img alt="plane.gif" src="assets/images/plane.gif"/>
# </em>
# </dl-root>
# <script src="assets/config/env.js"></script>
# <script src="assets/lib/swrcq.min.js"></script>
# <script src="assets/lib/Acc.DC.API.js"></script>
# <script src="assets/lib/calendar_generator.js"></script>
# <script src="assets/lib/aria_combobox_module.min.js"></script>
# <script src="assets/lib/read-text.js"></script>
# <script src="assets/lib/deque_datepicker.js"></script>
# <script defer="" src="runtime.js"></script>
# <script defer="" src="polyfills.js"></script>
# <script defer="" src="scripts.js"></script>
# <script defer="" src="main.js"></script>
# <script src="/iO81UL/OeDU0/CrrCt/gg/ciENJb9N7XV1/XiUsWQ/AlVcD/jQbRVo" type="text/javascript"></script></body>
# </html>
